# %%
import torch

tensor_to_load = "/private/home/francoisporcher/flow_matching/francois/temp/first_batch.pt"

tensor = torch.load(tensor_to_load)[0]

# %%
tensor.shape
# Out:
# torch.Size([32, 3, 64, 64])

# %%
import matplotlib.pyplot as plt

def visualize_image_i(tensor, i):
    image = tensor[i].permute(1, 2, 0).cpu().numpy()
    plt.imshow(image)
    plt.axis('off')
    plt.show()
    
visualize_image_i(tensor, 16)

# %%
import lovely_tensors as lt
lt.monkey_patch()

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True
